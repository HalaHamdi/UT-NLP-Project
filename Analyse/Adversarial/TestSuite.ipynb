# %%
predictions_file = '../../Data/trained_model/eval_squad_data/eval_predictions.jsonl'

# %%
from helper import run_analysis

# %%
run_analysis(predictions_file=predictions_file,output_file='Adversarial_Test_Suite_Report.md', model_name='AdvFinetuned')
