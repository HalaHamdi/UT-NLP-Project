# %%
from visualizations import read_models_data,create_custom_dashboard, create_checklist_dashboard

# %%
models_data = read_models_data()

# %%
create_custom_dashboard(models_data=models_data)

# %%
create_checklist_dashboard(models_data)
